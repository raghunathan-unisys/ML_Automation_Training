# %% [markdown]
# <a href="https://colab.research.google.com/github/raghunathan-unisys/ML_Automation_Training/blob/Training-Notes/Day_2_ML_TrainingNotes_20231220.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day - 2 - ML Training Notes

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

df = pd.read_csv("/content/Flipkart.csv", encoding="unicode_escape")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                1952 non-null   int64
#  1   Order Priority        1952 non-null   object
#  2   Discount              1952 non-null   float64
#  3   Unit Price            1952 non-null   float64
#  4   Shipping Cost         1952 non-null   float64
#  5   Customer ID           1952 non-null   int64
#  6   Customer Name         1952 non-null   object
#  7   Ship Mode             1952 non-null   object
#  8   Customer Segment      1952 non-null   object
#  9   Product Category      1952 non-null   object
#  10  Product Sub-Category  1952 non-null   object
#  11  Product Container     1952 non-null   object
#  12  Product Name          1952 non-null   object
#  13  Product Base Margin   1936 non-null   float64
#  14  Country               1952 non-null   object
# ...

# %% [markdown]
# ## Data Frames: Method loc and iloc

# %%
# loc - rows, coloumns
df1 = df.loc[10:20, ['Sales', 'Region', 'City']]
df1

# iloc - row, coloumns but coloumsn will in integer numbers
df1 = df.iloc[10:20, [23, 15, 17]]
df1
# Out:
#       Sales Region           City
# 10   945.99   East       Syracuse
# 11   455.77   West         Helena
# 12   231.79   West       Missoula
# 13  1876.69   East  New York City
# 14   293.06   East  New York City
# 15   914.29   East  New York City
# 16    67.49   West  Laguna Niguel
# 17     2.25   West  Laguna Niguel
# 18    54.78   West       Lakewood
# 19   424.68   West    Grants Pass

# %%
# Printing all Sales that are less than 100

df.loc[df['Sales'] < 100, ["Shipping Cost", "Ship Mode", "Sales"]]
# Out:
#       Shipping Cost    Ship Mode  Sales
# 0              0.93  Express Air  13.01
# 4              2.31  Regular Air  22.23
# 5              4.20  Regular Air  13.99
# 6              1.63  Regular Air  14.26
# 7              4.99  Regular Air  33.47
# ...             ...          ...    ...
# 1937           5.81  Regular Air  25.31
# 1939           2.03  Express Air  15.70
# 1941           0.50  Regular Air  28.34
# 1945           2.50  Regular Air  80.20
# 1949           5.81  Regular Air  59.98
#
# [715 rows x 3 columns]

# %%
# Printing Details of a customer by their name

print(df.loc[df['Customer Name']=='Tony Wilkins Winters','Discount':'Shipping Cost'])
# Out:
#     Discount  Unit Price  Shipping Cost
# 13      0.05       26.48           6.93
# 14      0.08        5.00           3.39
# 15      0.07       12.99           9.44

# %%
# Printing the Ship Mode with Air in the starting

df.loc[df['Ship Mode'].str.endswith("Air")]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      20847           High      0.01        2.84           0.93            3
# 2      21776       Critical      0.06        9.48           7.29           11
# 3      24844         Medium      0.09       78.69          19.99           14
# 4      24846         Medium      0.08        3.28           2.31           14
# 5      24847         Medium      0.05        3.28           4.20           14
# ...      ...            ...       ...         ...            ...          ...
# 1947   19842           High      0.01       10.90           7.46         3397
# 1948   19843           High      0.10        7.99           5.03         3397
# 1949   26208  Not Specified      0.08       11.97           5.81         3399
# 1950   24911         Medium      0.10        9.38           4.93         3400
# 1951   25914           High      0.10      105.98          13.99         3403
#
# ...

# %% [markdown]
# # Data Cleaning
#
# ## Handling missing values

# %%
# Link to file: https://docs.google.com/spreadsheets/d/1HCiNjXnmnH_Tsv1w-F1uZEK_
# b-oTAN8e/edit?usp=sharing&ouid=112067110865041380516&rtpof=true&sd=true

file_path = "/content/Missingvaluedatasample.xlsx"

df = pd.read_excel(file_path)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SN            10 non-null     int64
#  1   Product Name  10 non-null     object
#  2   Product ID    10 non-null     object
#  3   Sales Amount  5 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 448.0+ bytes

# %%
# Packages for Data Cleaning NON NON RELIABLE

# %%
pip install datacleaner
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for datacleaner: filename=datacleaner-0.1.5-py3-none-any.whl size=7408 sha256=230bab2aa403f4a1a7b3a6a5cd457d1eab54db32f02878ff5520648494425a03
#   Stored in directory: /root/.cache/pip/wheels/8f/bc/5b/f7ca5772f61851334a8580f3ede175b92a7122eef3464e2b3d
# Successfully built datacleaner
# ...

# %%
# Cleaning the data using installed Librabry NON RELIABLE

from datacleaner import autoclean
# df_cleaned = autoclean(df)
# print(df_cleaned.describe())

# %%
# Cleaning Data using Normal way
df_cleaned = df

# Checking for NULL Values
print(df.isnull().sum())
# Out:
# SN              0
# Product Name    0
# Product ID      0
# Sales Amount    5
# dtype: int64

# %% [markdown]
# # MQuery
# - The cleaning of data is much easier in Excel using MQuery
# - One such example for cleaning of spaces special charecters from a coloumn is this
# ```
# Text.Remove([Product Name],{" ".."@" , "[".."~"})
# ```

# %%
# TRYING HEATMAP

import pandas as pd

file_path = "/content/Flipkart.csv"

flipkart_df = pd.read_csv(file_path, encoding="unicode_escape")
flipkart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                1952 non-null   int64
#  1   Order Priority        1952 non-null   object
#  2   Discount              1952 non-null   float64
#  3   Unit Price            1952 non-null   float64
#  4   Shipping Cost         1952 non-null   float64
#  5   Customer ID           1952 non-null   int64
#  6   Customer Name         1952 non-null   object
#  7   Ship Mode             1952 non-null   object
#  8   Customer Segment      1952 non-null   object
#  9   Product Category      1952 non-null   object
#  10  Product Sub-Category  1952 non-null   object
#  11  Product Container     1952 non-null   object
#  12  Product Name          1952 non-null   object
#  13  Product Base Margin   1936 non-null   float64
#  14  Country               1952 non-null   object
# ...

# %%
# Displaying Heatmap for Flipkart Dataset

import seaborn as se
import matplotlib.pyplot as plt

df1 = flipkart_df[["Sales", "Region", "Shipping Cost", "Ship Mode"]].head(12)

# se.heatmap(df1, annot = True, fmt = ".1f")
plt.show()

# %% [markdown]
# # Matplot Lib
# - This is less interactive.
# - We will be using plotly or PowerBI instead in projects

# %%
# Using Glue Dataframe

import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
glue = sns.load_dataset('glue')
glue.head()
# Out:
#          Model  Year      Encoder  Task  Score
# 0        ERNIE  2019  Transformer  CoLA   75.5
# 1           T5  2019  Transformer  CoLA   71.6
# 2      RoBERTa  2019  Transformer  CoLA   67.8
# 3         BERT  2018  Transformer  CoLA   60.5
# 4  BiLSTM+ELMo  2018         LSTM  CoLA   32.1

# %%
glue = sns.load_dataset("glue").pivot(index="Model", columns="Task", values="Score")
sns.heatmap(glue)
# Out:
# <Axes: xlabel='Task', ylabel='Model'>

# %%
sns.heatmap(glue, annot=True)
# Out:
# <Axes: xlabel='Task', ylabel='Model'>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([10,8,4,23,89])
y = np.array([34,18,40,23,89])

plt.plot(x, y)
plt.show()

# %%
df1.head()

x = df1['Sales']
y = df1['Shipping Cost']
plt.plot(x, y)
plt.show()

# %%
y = np.array([2,4,1,6,9])

plt.plot(y, ">:g")

plt.plot(y, marker="o", ms="20", mec='r')

# %%
import numpy as np
import matplotlib.pyplot as plt

x = df1['Sales']
y = df1['Shipping Cost']

plt.xlabel("Sales Values")
plt.ylabel("Shipping Cost Values")
plt.title("My Plot")

# # Normal Plotting
# plt.plot(x,y)
# plt.show()

# Scatter Plot
plt.scatter(x,y)
plt.show()

# %% [markdown]
# # PlotLy Inteactive Plots
# - These are more interactive plots
#
# ```
# pip install plotly
# ```

# %%
pip install plotly

# %%
import plotly.express as px
import numpy as np
import matplotlib.pyplot as plt

x = df1['Sales']
y = df1['Shipping Cost']

plt.xlabel("Sales Values")
plt.ylabel("Shipping Cost Values")
plt.title("My Plot")

# Scatter Plot using Plotly
fig = px.scatter(x,y)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Createing a Pyplot for Region and Sales

fig = px.pie(df1 , values = "Sales" , names = "Region")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Machine Learning Models
